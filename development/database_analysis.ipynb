# %% [markdown]
# ## Read in and check data

# %%
import pandas
import numpy

# %%
infile = '/Users/damienirving/Documents/Professional/Scientific_computing/git_repo/phd/development/zw3-w19-va-stats-threshold75pct_ERAInterim_500hPa_090day-runmean_native-mermax-lat70S40S.csv'

# %%
df = pandas.read_csv(infile, index_col=0)

# %%
df.columns
# Out:
# Index([u'wave1_amp_middle', u'wave1_amp_max', u'wave1_phase_middle', u'wave2_amp_middle', u'wave2_amp_max', u'wave2_phase_middle', u'wave3_amp_middle', u'wave3_amp_max', u'wave3_phase_middle', u'wave4_amp_middle', u'wave4_amp_max', u'wave4_phase_middle', u'wave5_amp_middle', u'wave5_amp_max', u'wave5_phase_middle', u'wave6_amp_middle', u'wave6_amp_max', u'wave6_phase_middle', u'wave7_amp_middle', u'wave7_amp_max', u'wave7_phase_middle', u'wave8_amp_middle', u'wave8_amp_max', u'wave8_phase_middle', u'wave9_amp_middle', u'wave9_amp_max', u'wave9_phase_middle', u'ZW3_index', u'env_amp_mean', u'env_extent', u'env_start_lon', u'env_end_lon', u'nenv_amp_mean', u'nenv_extent', u'nenv_start_lon', u'nenv_end_lon'], dtype='object')

# %%
df['env_amp_mean'][-5:]
# Out:
# 2014-04-13    5.09
# 2014-04-14    5.02
# 2014-04-15    4.95
# 2014-04-16    4.89
# 2014-04-17    4.85
# Name: env_amp_mean, dtype: float64

# %%
len(df['ZW3_index'])
# Out:
# 12846

# %% [markdown]
# ## Phase analysis

# %% [markdown]
# It appears that the phase of all wavenumbers isn't random. In other words, the observation that wave 1 and 3 aren't random can't really be shown objectively, because they require modulation in common ways.

# %%
# %matplotlib inline

# %%
df['wave1_phase_middle'].plot(kind='density', xlim=[0, 360])

# %%
print df['wave2_phase_middle'][:].min()
print df['wave2_phase_middle'][:].max()
df['wave2_phase_middle'].plot(kind='density', xlim=(0, 180))
# Out:
# 0.0
# 179.25

# %%
print df['wave3_phase_middle'][:].min()
print df['wave3_phase_middle'][:].max()
df['wave3_phase_middle'].plot(kind='density', xlim=(0, 120))
# Out:
# 0.0
# 119.25

# %%
print df['wave4_phase_middle'][:].min()
print df['wave4_phase_middle'][:].max()
df['wave4_phase_middle'].plot(kind='density', xlim=(0, 90))
# Out:
# 0.0
# 89.25

# %%
print df['wave5_phase_middle'][:].min()
print df['wave5_phase_middle'][:].max()
df['wave5_phase_middle'].plot(kind='density', xlim=(0, 360/5.))
# Out:
# 0.0
# 71.25

# %%
print df['wave6_phase_middle'][:].min()
print df['wave6_phase_middle'][:].max()
df['wave6_phase_middle'].plot(kind='density', xlim=(0, 360/6.))
# Out:
# 0.0
# 59.25

# %%
print df['wave7_phase_middle'][:].min()
print df['wave7_phase_middle'][:].max()
df['wave7_phase_middle'].plot(kind='density', xlim=(0, 360/7.))
# Out:
# 0.0
# 51.0

# %% [markdown]
# ## Index comparison

# %%
quad_index_comparison = df[['ZW3_index', 'nenv_amp_mean', 'env_amp_mean', 'wave3_amp_max']]
quad_index_comparison.corr()
# Out:
#                ZW3_index  nenv_amp_mean  env_amp_mean  wave3_amp_max
# ZW3_index       1.000000       0.295054      0.345406       0.525700
# nenv_amp_mean   0.295054       1.000000      0.725885       0.560975
# env_amp_mean    0.345406       0.725885      1.000000       0.757837
# wave3_amp_max   0.525700       0.560975      0.757837       1.000000
#
# [4 rows x 4 columns]

# %% [markdown]
# Keep in mind that since we are really only interested in the large values of these indices, some of the discrepancy in correlation might arise in mid-to-low values, which we don't really care about so much.

# %% [markdown]
# For ease of comparsion, we should go ahead and normalise these indices so that they can be compared on the same plot...

# %%
def normalise_series(series):
    """Normalise a Pandas data series by subtracting the
    mean and dividing by the stdev"""

    ave = series.mean()
    stdev = series.std()
    
    return (series - ave) / stdev

# %%
df['env_amp_mean_norm'] = normalise_series(df['env_amp_mean'])
df['nenv_amp_mean_norm'] = normalise_series(df['nenv_amp_mean'])
df['ZW3_index_norm'] = normalise_series(df['ZW3_index'])
df['wave3_amp_max_norm'] = normalise_series(df['wave3_amp_max'])

# %%
df['wave3_amp_max']
# Out:
# 1979-02-15    3.49
# 1979-02-16    3.49
# 1979-02-17    3.49
# 1979-02-18    3.46
# 1979-02-19    3.42
# 1979-02-20    3.38
# 1979-02-21    3.36
# 1979-02-22    3.33
# 1979-02-23    3.34
# 1979-02-24    3.38
# 1979-02-25    3.46
# 1979-02-26    3.52
# 1979-02-27    3.52
# 1979-02-28    3.48
# 1979-03-01    3.47
# ...
# 2014-04-03    3.58
# 2014-04-04    3.59
# 2014-04-05    3.62
# 2014-04-06    3.63
# 2014-04-07    3.60
# 2014-04-08    3.54
# 2014-04-09    3.49
# 2014-04-10    3.41
# 2014-04-11    3.29
# 2014-04-12    3.19
# 2014-04-13    3.10
# 2014-04-14    3.03
# 2014-04-15    2.98
# 2014-04-16    2.92
# 2014-04-17    2.85
# Name: wave3_amp_max, Length: 12846, dtype: float64

# %% [markdown]
# ### Plotting with Pandas

# %% [markdown]
# Plot the indices of interest

# %%
columns_for_plot = df[['env_amp_mean_norm', 'nenv_amp_mean_norm', 'ZW3_index_norm', 'wave3_amp_max_norm']]

start_index = list(df.index).index('1989-01-01')
end_index = list(df.index).index('1989-12-31')

columns_for_plot[start_index:end_index].plot()

# %% [markdown]
# Here's the local maxima on the curve... (I might need to play around with order, which determines how many surrounding grid points to consider)

# %%
from scipy import signal

# %%
maxima_indexes = signal.argrelextrema(numpy.array(df['env_amp_mean']), numpy.greater, order=90)
df['env_amp_mean'][list(maxima_indexes)[0]]
# Out:
# 1979-08-28    5.55
# 1980-05-19    7.42
# 1982-07-18    6.30
# 1983-01-11    4.77
# 1983-05-25    5.77
# 1983-09-30    4.91
# 1984-06-15    6.22
# 1985-01-17    4.71
# 1985-05-19    5.94
# 1985-09-28    5.90
# 1986-07-02    5.80
# 1986-10-30    5.40
# 1987-01-31    5.29
# 1987-07-14    5.51
# 1988-06-02    6.79
# 1989-01-25    4.53
# 1989-08-23    7.51
# 1990-07-13    4.64
# 1991-06-23    6.78
# 1992-03-21    6.32
# 1992-10-15    5.15
# 1993-03-12    6.19
# 1994-05-02    5.10
# 1996-08-17    5.38
# 1997-01-25    4.66
# 1997-06-28    6.39
# 1999-01-07    5.75
# 1999-08-26    6.20
# 2000-07-30    6.71
# 2001-11-23    5.17
# 2003-08-23    5.33
# 2004-02-28    5.75
# 2004-06-27    5.44
# 2005-10-10    7.02
# 2006-04-22    6.07
# 2006-08-29    6.41
# 2007-05-31    6.22
# 2009-07-06    5.54
# 2009-11-14    5.18
# 2011-08-24    5.66
# 2012-04-06    5.63
# 2012-08-18    5.89
# 2013-03-13    5.03
# 2014-03-23    5.98
# Name: env_amp_mean, dtype: float64

# %% [markdown]
# #### Difference between indices

# %% [markdown]
# env versus ZW3

# %%
# env vs. zw3
df['diff_env_zw3'] = df['env_amp_mean_norm'] - df['ZW3_index_norm']

start_index = list(df.index).index('1986-01-01')
end_index = list(df.index).index('1986-12-31')

df['diff_env_zw3'][start_index:end_index].plot()

# %%
# Find the points of largest difference
diff_env_gt_zw3_indexes = signal.argrelextrema(numpy.array(df['diff_env_zw3']), numpy.greater, order=90)
print 'env > zw3'
print df['diff_env_zw3'][list(diff_env_gt_zw3_indexes)[0]]

diff_env_lt_zw3_indexes = signal.argrelextrema(numpy.array(df['diff_env_zw3']), numpy.less, order=90)
print 'env < zw3'
print df['diff_env_zw3'][list(diff_env_lt_zw3_indexes)[0]]
# Out:
# env > zw3
# 1979-03-17    0.200316
# 1979-09-01    3.509172
# 1980-07-08    2.225311
# 1980-12-20    0.234207
# 1981-06-22    1.976175
# 1982-04-12    1.751790
# 1983-05-26    1.103119
# 1984-06-15    1.806838
# 1985-01-13    0.734697
# 1985-06-02    0.526973
# 1985-09-27    0.886912
# 1986-06-30    4.136479
# 1987-01-31    0.593891
# 1987-08-25    0.484148
# 1988-07-31    3.122666
# 1989-08-07    3.130186
# 1990-05-12    1.241000
# 1991-02-12    1.597503
# 1991-06-25    2.706107
# 1992-05-31    2.097287
# 1992-09-22    2.396121
# 1993-05-23    0.905654
# 1994-04-18    0.493995
# 1994-09-05    2.091485
# 1995-06-30    4.539499
# 1996-03-06    1.414883
# 1996-09-18    0.576013
# 1997-06-27    1.539471
# 1997-10-23    1.052970
# 1998-03-01    0.409150
# 1998-07-11    0.176478
# 1999-04-03    0.551773
# 1999-08-21   -0.370077
# 2000-03-12    1.422305
# 2000-07-30    1.240235
# 2001-02-02    1.382003
# 2001-06-26    2.246272
# 2001-11-27    2.950197
# 2002-05-05    2.907617
# 2003-01-20    0.912321
# 2003-05-06    0.871557
# 2003-09-20    2.136480
# 2004-02-28    1.623864
# 2004-08-09    2.189407
# 2005-06-15    2.330312
# 2006-04-21    3.504322
# 2007-05-24    2.409905
# 2008-08-25    2.703231
# 2009-04-11    1.048022
# 2009-11-14    3.797903
# 2010-09-28    2.834288
# 2011-03-12    1.651393
# 2011-06-18    2.039667
# 2012-08-22    1.377860
# 2013-05-20    0.599703
# 2013-10-20   -0.065128
# 2014-03-23    1.958552
# Name: diff_env_zw3, Length: 57, dtype: float64
# env < zw3
# 1979-07-10   -1.040259
# 1979-12-18   -1.199042
# 1980-09-11   -1.646909
# 1981-03-06   -1.429288
# 1981-11-22   -2.413403
# 1982-11-27   -1.317267
# 1983-03-17   -0.422897
# 1983-11-24   -1.368987
# 1984-04-03   -0.543352
# 1984-11-14   -1.863519
# 1985-07-17   -0.442700
# 1985-12-19   -1.907306
# 1986-04-14   -1.115355
# 1986-11-13   -1.791250
# 1987-04-27   -1.955688
# 1987-11-03   -2.173309
# 1988-10-31   -1.588425
# 1990-02-11   -1.916751
# 1990-10-16   -1.010609
# 1991-04-24   -0.097300
# 1991-10-20   -0.910006
# 1992-08-05    0.107037
# 1993-02-19   -0.872738
# 1993-11-16   -2.566531
# 1994-12-04   -2.385373
# 1995-10-05   -2.131289
# 1996-06-19   -1.292576
# 1996-11-19   -1.474941
# 1997-02-28   -0.830414
# 1997-12-13   -1.796650
# 1998-12-15   -2.966625
# 1999-06-18   -1.691708
# 1999-11-04   -2.209419
# 2000-05-24   -0.718952
# 2000-11-22   -2.151592
# 2001-03-20   -1.125104
# 2001-08-07   -0.422750
# 2002-03-05   -0.947176
# 2002-11-21   -1.574788
# 2003-04-05   -1.163540
# 2004-01-01   -1.737459
# 2004-05-04   -0.817385
# 2004-10-03   -1.531658
# 2005-03-11   -1.302825
# 2005-11-21   -2.150433
# 2006-09-27   -1.615797
# 2007-02-21   -2.115433
# 2007-11-25   -2.776121
# 2008-04-23   -1.728976
# 2008-11-16   -1.328833
# 2009-07-09   -1.385354
# 2010-03-24   -1.619380
# 2011-01-11   -0.692435
# 2011-05-20   -0.556125
# 2011-12-25   -1.431762
# 2012-12-20   -1.838974
# 2013-08-06   -1.356764
# 2013-12-27   -1.276160
# Name: diff_env_zw3, Length: 58, dtype: float64

# %% [markdown]
# env versus wave 3

# %%
# env vs. wave3

df['diff_env_wave3'] = df['env_amp_mean_norm'] - df['wave3_amp_max_norm']

start_index = list(df.index).index('1989-01-01')
end_index = list(df.index).index('1989-12-31')

df['diff_env_wave3'][start_index:end_index].plot()

# %%
# Find the points of largest difference
diff_env_gt_wave3_indexes = signal.argrelextrema(numpy.array(df['diff_env_wave3']), numpy.greater, order=90)
print 'env > wave3'
print df['diff_env_wave3'][list(diff_env_gt_wave3_indexes)[0]]

diff_env_lt_wave3_indexes = signal.argrelextrema(numpy.array(df['diff_env_wave3']), numpy.less, order=90)
print 'env < wave3'
print df['diff_env_wave3'][list(diff_env_lt_wave3_indexes)[0]]
# Out:
# env > wave3
# 1979-09-12    1.476562
# 1980-05-16    2.196603
# 1980-12-22    1.287814
# 1981-07-29    0.824915
# 1982-01-11   -0.215909
# 1982-07-19    1.029874
# 1983-03-07    0.903835
# 1983-07-14    0.913554
# 1983-12-15    0.717124
# 1984-05-22    0.977292
# 1984-12-09    0.081925
# 1985-05-30    1.007990
# 1985-09-27    1.120188
# 1986-03-07    1.072670
# 1986-07-14    0.976749
# 1986-12-17    0.285570
# 1987-07-14    0.995949
# 1988-03-05    0.908604
# 1988-07-29    1.942574
# 1989-08-27    2.212699
# 1991-05-17    1.062894
# 1991-09-06    1.506841
# 1992-04-19    2.445367
# 1993-02-12    0.722493
# 1993-05-25    1.095677
# 1994-04-14    0.851558
# 1994-11-14    0.304940
# 1995-05-19    1.068729
# 1995-12-30    0.878915
# 1996-12-19    0.587221
# 1997-06-28    1.878075
# 1997-12-26    0.571419
# 1998-07-12    0.735905
# 1999-04-21    0.023508
# 2000-03-28    0.610181
# 2000-07-30    0.756304
# 2001-02-13    1.363174
# 2001-06-19    0.555876
# 2001-10-12    0.628713
# 2002-04-19    1.521520
# 2003-05-18    0.842201
# 2004-07-19    1.518112
# 2004-11-28    1.664701
# 2005-06-15    2.911017
# 2006-06-30    1.625065
# 2007-01-10    1.110640
# 2007-09-03    0.587583
# 2008-08-07    1.138607
# 2009-04-18    1.461599
# 2009-09-27    1.501654
# 2010-07-19    2.011310
# 2010-12-22    0.880885
# 2011-08-16    0.558788
# 2012-07-03    1.890344
# 2012-12-31    0.604926
# 2013-05-05    0.632168
# 2014-02-15    1.328297
# Name: diff_env_wave3, Length: 57, dtype: float64
# env < wave3
# 1979-03-05   -1.225368
# 1980-01-24   -1.051469
# 1980-09-12   -0.676257
# 1981-03-18   -0.889735
# 1981-11-22   -1.410061
# 1982-11-09   -0.665948
# 1983-11-01   -0.530495
# 1984-10-16   -0.911143
# 1985-12-24   -0.968789
# 1986-09-26   -1.066908
# 1987-05-25   -1.182505
# 1987-11-03   -1.493579
# 1988-05-05   -0.509506
# 1989-02-08   -1.158003
# 1990-03-15   -1.118481
# 1990-06-18   -1.107868
# 1991-02-18   -1.271924
# 1991-08-08   -0.216747
# 1991-12-11   -0.027827
# 1992-08-05    0.367422
# 1992-12-17   -0.707374
# 1993-10-11   -1.303165
# 1994-02-18   -0.898921
# 1994-09-24   -0.527878
# 1995-03-26   -1.244149
# 1995-10-05   -0.862140
# 1996-06-20   -1.072753
# 1996-11-03   -1.098092
# 1997-02-23   -0.965448
# 1997-11-30   -0.557986
# 1998-04-14   -0.741470
# 1998-12-15   -1.333092
# 1999-09-09   -1.249564
# 2000-05-17   -0.906907
# 2000-11-24   -1.189901
# 2001-03-24   -0.832146
# 2001-08-26   -0.745287
# 2002-01-10   -0.594281
# 2002-07-27   -0.314028
# 2002-11-30   -0.863987
# 2003-03-20   -0.679350
# 2003-07-20   -0.703738
# 2004-01-25   -1.336071
# 2005-03-12   -1.084680
# 2005-11-22   -0.957099
# 2006-09-24   -0.507908
# 2007-02-24   -1.490000
# 2008-02-10   -1.267993
# 2008-05-27   -1.271391
# 2008-12-22   -1.054096
# 2009-07-05   -1.381314
# 2010-03-02   -1.148352
# 2011-01-30   -1.727979
# 2011-12-06   -1.346923
# 2012-10-30   -0.925688
# 2013-02-26   -0.964848
# 2013-08-05   -0.592558
# 2014-04-16    0.174572
# Name: diff_env_wave3, Length: 58, dtype: float64

# %% [markdown]
# ### Plotting with `plot_timeseries.py`

# %%
# %run ../visualisation/plot_timeseries.py DAILY /home/dbirving/Downloads/Data/zw3-zg_ERAInterim_500hPa_090day-runmean-zonal-anom_native.nc zw3 1 zw3 --primary /home/dbirving/Downloads/Data/env-w29-va-stats-threshold75pct_ERAInterim_500hPa_090day-runmean_native-mermax-lat70S40S.nc amp_mean 1 env --primary /home/dbirving/Downloads/Data/nenv-w29-va-stats-threshold75pct_ERAInterim_500hPa_090day-runmean_native-mermax-lat70S40S.nc amp_mean 1 nenv --ploc 3 --nrows 3 --normalise --legsize xx-small
# Out:
# major tick interval: 612
# showing...

# %%
# %run ../visualisation/plot_timeseries.py DAILY /home/dbirving/Downloads/Data/zw3-zg_ERAInterim_500hPa_090day-runmean-zonal-anom_native.nc zw3 1 zw3 --primary /home/dbirving/Downloads/Data/env-w29-va-stats-threshold75pct_ERAInterim_500hPa_090day-runmean_native-mermax-lat70S40S.nc amp_mean 1 env --primary /home/dbirving/Downloads/Data/nenv-w29-va-stats-threshold75pct_ERAInterim_500hPa_090day-runmean_native-mermax-lat70S40S.nc amp_mean 1 nenv --ploc 3 --normalise --xmin 2003-01-01 --xmax 2003-12-31
# Out:
# major tick interval: 53
# showing...
