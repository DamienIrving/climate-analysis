# %% [markdown]
# ## Read in and check data

# %%
import pandas
import numpy

# %%
df = pandas.read_csv('/home/dbirving/Documents/Professional/Scientific_computing/git_repo/phd/development/zw3-w29-va-stats-threshold75pct_ERAInterim_500hPa_090day-runmean_native-mermax-lat70S40S.csv', index_col=0)

# %%
df['wave1_amp'][0:10]
# Out:
# 1979-02-15    1.274546
# 1979-02-16    1.275353
# 1979-02-17    1.299404
# 1979-02-18    1.346212
# 1979-02-19    1.380249
# 1979-02-20    1.409762
# 1979-02-21    1.445882
# 1979-02-22    1.472897
# 1979-02-23    1.491208
# 1979-02-24    1.494560
# Name: wave1_amp, dtype: float64

# %%
df.columns
# Out:
# Index([u'wave1_amp', u'wave1_phase', u'wave2_amp', u'wave2_phase', u'wave3_amp', u'wave3_phase', u'wave4_amp', u'wave4_phase', u'wave5_amp', u'wave5_phase', u'wave6_amp', u'wave6_phase', u'wave7_amp', u'wave7_phase', u'wave8_amp', u'wave8_phase', u'wave9_amp', u'wave9_phase', u'ZW3_index', u'env_amp-mean', u'env_start-lon', u'env_end-lon', u'env_extent', u'nenv_amp-mean', u'nenv_start-lon', u'nenv_end-lon', u'nenv_extent'], dtype=object)

# %%
len(df['ZW3_index'])
# Out:
# 12846

# %% [markdown]
# ## Phase analysis

# %% [markdown]
# It appears that the phase of all wavenumbers isn't random. In other words, the observation that wave 1 and 3 aren't random can't really be shown objectively, because they require modulation in common ways.

# %%
# %matplotlib inline

# %%
df['wave1_phase'].plot(kind='density', xlim=[0, 360])

# %%
print df['wave2_phase'][:].min()
print df['wave2_phase'][:].max()
df['wave2_phase'].plot(kind='density', xlim=(0, 180))
# Out:
# 0.0
# 179.25

# %%
print df['wave3_phase'][:].min()
print df['wave3_phase'][:].max()
df['wave3_phase'].plot(kind='density', xlim=(0, 120))
# Out:
# 0.0
# 119.25

# %%
print df['wave4_phase'][:].min()
print df['wave4_phase'][:].max()
df['wave4_phase'].plot(kind='density', xlim=(0, 90))
# Out:
# 0.0
# 89.25

# %%
print df['wave5_phase'][:].min()
print df['wave5_phase'][:].max()
df['wave5_phase'].plot(kind='density', xlim=(0, 360/5.))
# Out:
# 0.0
# 71.25

# %%
print df['wave6_phase'][:].min()
print df['wave6_phase'][:].max()
df['wave6_phase'].plot(kind='density', xlim=(0, 360/6.))
# Out:
# 0.0
# 59.25

# %%
print df['wave7_phase'][:].min()
print df['wave7_phase'][:].max()
df['wave7_phase'].plot(kind='density', xlim=(0, 360/7.))
# Out:
# 0.0
# 51.0

# %% [markdown]
# ## Index comparison

# %%
quad_index_comparison = df[['ZW3_index', 'nenv_amp-mean', 'env_amp-mean', 'wave3_amp']]
quad_index_comparison.corr()
# Out:
#                ZW3_index  nenv_amp-mean  env_amp-mean  wave3_amp
# ZW3_index       1.000000       0.351650      0.388814   0.563334
# nenv_amp-mean   0.351650       1.000000      0.818590   0.563618
# env_amp-mean    0.388814       0.818590      1.000000   0.761939
# wave3_amp       0.563334       0.563618      0.761939   1.000000

# %% [markdown]
# Keep in mind that since we are really only interested in the large values of these indices, some of the discrepancy in correlation might arise in mid-to-low values, which we don't really care about so much.

# %%
double_index_comparison = df[['ZW3_index', 'nenv_amp-mean']]
double_index_comparison[0:5]
# Out:
#             ZW3_index  nenv_amp-mean
# 1979-02-15   0.164217       1.161640
# 1979-02-16   0.153156       1.150779
# 1979-02-17   0.135397       1.106842
# 1979-02-18   0.144116       1.028354
# 1979-02-19   0.114837       0.925253

# %%
double_index_comparison[600:1500].plot()
